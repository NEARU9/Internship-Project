# %%
import pandas as pd

# List nama file CSV
files = [
    'sinoptik 2025-02-28 to 2025-03-01.csv',
    'sinoptik 2025-03-01 to 2025-03-02.csv',
    'sinoptik 2025-03-02 to 2025-03-03.csv',
    'sinoptik 2025-03-03 to 2025-03-04.csv',
    'sinoptik 2025-03-04 to 2025-03-05.csv',
    'sinoptik 2025-03-05 to 2025-03-06.csv',
    'sinoptik 2025-03-06 to 2025-03-07.csv',
    'sinoptik 2025-03-07 to 2025-03-08.csv',
    'sinoptik 2025-03-08 to 2025-03-09.csv',
    'sinoptik 2025-03-09 to 2025-03-10.csv',
    'sinoptik 2025-03-10 to 2025-03-11.csv',
    'sinoptik 2025-03-11 to 2025-03-12.csv',
    'sinoptik 2025-03-12 to 2025-03-13.csv',
    'sinoptik 2025-03-13 to 2025-03-14.csv',
    'sinoptik 2025-03-14 to 2025-03-15.csv',
    'sinoptik 2025-03-15 to 2025-03-16.csv',
    'sinoptik 2025-03-16 to 2025-03-17.csv',
    'sinoptik 2025-03-17 to 2025-03-18.csv',
    'sinoptik 2025-03-18 to 2025-03-19.csv',
    'sinoptik 2025-03-19 to 2025-03-20.csv',
    'sinoptik 2025-03-20 to 2025-03-21.csv',
    'sinoptik 2025-03-21 to 2025-03-22.csv',
    'sinoptik 2025-03-22 to 2025-03-23.csv',
    'sinoptik 2025-03-23 to 2025-03-24.csv',
    'sinoptik 2025-03-24 to 2025-03-25.csv',
    'sinoptik 2025-03-25 to 2025-03-26.csv',
    'sinoptik 2025-03-26 to 2025-03-27.csv',
    'sinoptik 2025-03-27 to 2025-03-28.csv',
    'sinoptik 2025-03-28 to 2025-03-29.csv',
    'sinoptik 2025-03-29 to 2025-03-30.csv',
    'sinoptik 2025-03-30 to 2025-03-31.csv',
    'sinoptik 2025-03-31 to 2025-04-01.csv',
    'sinoptik 2025-04-01 to 2025-04-02.csv',
    'sinoptik 2025-04-02 to 2025-04-03.csv',
    'sinoptik 2025-04-03 to 2025-04-04.csv',
    'sinoptik 2025-04-04 to 2025-04-05.csv',
    'sinoptik 2025-04-05 to 2025-04-06.csv',
    'sinoptik 2025-04-06 to 2025-04-07.csv',
    # 'sinoptik 2025-04-07 to 2025-04-08.csv', 
    # 'sinoptik 2025-04-08 to 2025-04-09.csv',
    # 'sinoptik 2025-04-09 to 2025-04-10.csv',
    # 'sinoptik 2025-04-10 to 2025-04-11.csv',
    # 'sinoptik 2025-04-11 to 2025-04-12.csv',
    # 'sinoptik 2025-04-12 to 2025-04-13.csv',
    # 'sinoptik 2025-04-13 to 2025-04-14.csv',
    # 'sinoptik 2025-04-14 to 2025-04-15.csv',
    # 'sinoptik 2025-04-15 to 2025-04-16.csv',
    # 'sinoptik 2025-04-16 to 2025-04-17.csv',
    # 'sinoptik 2025-04-17 to 2025-04-18.csv',
    # 'sinoptik 2025-04-18 to 2025-04-19.csv',
    # 'sinoptik 2025-04-19 to 2025-04-20.csv',
    'sinoptik 2025-04-20 to 2025-04-21.csv',
    # 'sinoptik 2025-04-21 to 2025-04-22.csv',
    'sinoptik 2025-04-22 to 2025-04-23.csv',
    'sinoptik 2025-04-23 to 2025-04-24.csv',
    'sinoptik 2025-04-24 to 2025-04-25.csv',
    'sinoptik 2025-04-25 to 2025-04-26.csv',
    'sinoptik 2025-04-26 to 2025-04-27.csv',
    'sinoptik 2025-04-27 to 2025-04-28.csv',
    # 'sinoptik 2025-04-28 to 2025-04-29.csv',
    # 'sinoptik 2025-04-29 to 2025-04-30.csv',
    # 'sinoptik 2025-04-30 to 2025-05-01.csv',
    'sinoptik 2025-05-01 to 2025-05-02.csv',
    'sinoptik 2025-05-02 to 2025-05-03.csv',
    'sinoptik 2025-05-03 to 2025-05-04.csv',
    'sinoptik 2025-05-04 to 2025-05-05.csv',
    'sinoptik 2025-05-05 to 2025-05-06.csv',
    'sinoptik 2025-05-06 to 2025-05-07.csv',
    'sinoptik 2025-05-07 to 2025-05-08.csv',
    'sinoptik 2025-05-08 to 2025-05-09.csv',
    'sinoptik 2025-05-09 to 2025-05-10.csv',
    'sinoptik 2025-05-10 to 2025-05-11.csv',
    'sinoptik 2025-05-11 to 2025-05-12.csv',
    'sinoptik 2025-05-12 to 2025-05-13.csv',
    'sinoptik 2025-05-13 to 2025-05-14.csv',
    'sinoptik 2025-05-14 to 2025-05-15.csv',
    'sinoptik 2025-05-15 to 2025-05-16.csv',
    'sinoptik 2025-05-16 to 2025-05-17.csv',
    'sinoptik 2025-05-17 to 2025-05-18.csv',
    'sinoptik 2025-05-18 to 2025-05-19.csv',
    'sinoptik 2025-05-19 to 2025-05-20.csv',
    'sinoptik 2025-05-20 to 2025-05-21.csv',
    'sinoptik 2025-05-21 to 2025-05-22.csv',
    'sinoptik 2025-05-22 to 2025-05-23.csv',
    'sinoptik 2025-05-23 to 2025-05-24.csv',
    'sinoptik 2025-05-24 to 2025-05-25.csv',
    'sinoptik 2025-05-25 to 2025-05-26.csv',
    'sinoptik 2025-05-26 to 2025-05-27.csv',
    'sinoptik 2025-05-27 to 2025-05-28.csv',
    'sinoptik 2025-05-28 to 2025-05-29.csv',
    'sinoptik 2025-05-29 to 2025-05-30.csv',
    # 'sinoptik 2025-05-30 to 2025-05-31.csv',
    'sinoptik 2025-05-31 to 2025-06-01.csv',
    'sinoptik 2025-06-01 to 2025-06-02.csv',
    'sinoptik 2025-06-02 to 2025-06-03.csv',
    'sinoptik 2025-06-03 to 2025-06-04.csv',
    'sinoptik 2025-06-04 to 2025-06-05.csv',
    'sinoptik 2025-06-05 to 2025-06-06.csv'

]

dfs = []
for file in files:
    # Baca file dengan skip baris pertama
    df = pd.read_csv(file, skiprows=1)
    dfs.append(df)

# Gabungkan semua DataFrame secara vertikal
combined_df = pd.concat(dfs, ignore_index=True)

combined_df

# %%
# Simpan ke file CSV (tanpa index)
combined_df.to_csv('data_cuaca_gabungan.csv', index=False)

print("Data berhasil disimpan")
